# %% [markdown]
# ## Experimental results for "A Shared-Memory Algorithm for Updating Tree-Based Properties of Large Dynamic Networks"
# Edit the variables below to indicate which plots to generate, the algs list is a list of subdirectories with log files containing time, power, and energy measurements. The MST time, power, and energy totals include only the update values (not the building of the rooted tree, which is a one-time initial cost).

# %%
from Power2_revised import *
#algs = ['MST/output-16epv','MST/output-8epv','MST/output-real','CC/output-16epv','CC/output-8epv','CC/output-real']
algs = ['MST/output-8epv-new','MST/output-real-new']  # Recreated for the major journal submission revisions
whats = {'Energy':'Total CPU Energy (J)','Power':'Average CPU Power (W)', 'Memory':'Total Memory (GB)','Time':'Time (seconds)'}
speedup = False
epvs = ['8']
nws = ['ER','G']
insperc = ['100','75']
root = True
speedup = False
printData = True

algnames = [x.split('/')[0] for x in algs]
for algfull in algs:
    alg = algfull.split('/')[0]
    processData(alg)
# Out:
# MST Power com-lj-org-weighted_75i_1000000
# Data for plot:
#       what                          Network  Threads  MST-ins-p0  MST-ins-p1  \
# id
# 88   Power  com-lj-org-weighted_75i_1000000        1   61.293167   74.523478
# 200  Power  com-lj-org-weighted_75i_1000000        2   58.770200   70.773175
# 132  Power  com-lj-org-weighted_75i_1000000        4   57.741087   68.284388
# 76   Power  com-lj-org-weighted_75i_1000000        8   58.524575   75.764413
# 104  Power  com-lj-org-weighted_75i_1000000       16   56.319088   71.858338
# 120  Power  com-lj-org-weighted_75i_1000000       32   61.546637   67.608662
# 0    Power  com-lj-org-weighted_75i_1000000       48   52.055388   70.013963
# 192  Power  com-lj-org-weighted_75i_1000000       64   52.512638   60.162900
# 32   Power  com-lj-org-weighted_75i_1000000       72   48.439212   53.707625
#
#      MST-del-p0  MST-del-p1   MST-Total  MST-root-p0  MST-root-p1  ...    \
# ...
